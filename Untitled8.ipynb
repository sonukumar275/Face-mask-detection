# %%
import numpy as np
import cv2

# %%
with_mask = np.load('with_mask.npy')
without_mask = np.load('without_mask.npy')

# %%
with_mask.shape
# Out:
# (200, 50, 50, 3)

# %%
without_mask.shape
# Out:
# (200, 50, 50, 3)

# %%
with_mask.shape
# Out:
# (200, 50, 50, 3)

# %%
with_mask = with_mask.reshape(200,50*50*3)
without_mask = without_mask.reshape(200,50*50*3)

# %%
without_mask.shape
# Out:
# (200, 7500)

# %%
with_mask.shape
# Out:
# (200, 7500)

# %%
X = np.r_[with_mask, without_mask]

# %%
X.shape
# Out:
# (400, 7500)

# %%
labels = np.zeros(X.shape[0])

# %%
labels[200:] = 1.0

# %%
name = {0: 'mask',1 : 'NO Mask'}

# %%
#SVM - support Vector Machine
#SVC - Support Vector Classification
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,labels, test_size=0.25)

# %%
x_train.shape
# Out:
# (300, 7500)

# %%
# Reduceing the dimesion
# PCA - Principal Component Analysis
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
x_train = pca.fit_transform(x_train)

# %%
x_train[0]
# Out:
# array([-2703.3595108 ,  -543.33543994, -1118.74647912])

# %%
x_train.shape
# Out:
# (300, 3)

# %%
svm = SVC()
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
x_test = pca.transform(x_test)
y_pred = svm.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.77

# %%
haar_data = cv2.CascadeClassifier(r'E:\DataSet\dataset\data.xml')
capture = cv2.VideoCapture(0) # for viedo just drop the path of video
data = []
while True:
    flag, img = capture.read()
    if flag: 
        faces = haar_data.detectMultiScale(img)
        for x,y,w,h in faces:
            cv2.rectangle(img,(x,y),(x+w, y+h), (255,0,255),4)
            face = img[y:y+h, x:x+w, :]
            face = cv2.resize(face,(50,50))
            face = face.reshape(1,-1)
            face = pca.transform(face)
            pred = svm.predict(face)[0]
            n = name[int(pred)]
            print(n)
            
        cv2.imshow('result',img)
        if cv2.waitKey(4) == 27:
            break
        
capture.release()
cv2.destroyAllWindows()
# Out:
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# NO Mask
# mask
# NO Mask
# NO Mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# mask
# mask
# NO Mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# mask
# NO Mask
# NO Mask
# mask
# mask
# mask
# NO Mask
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 7
#       5 flag, img = capture.read()
#       6 if flag:
# ----> 7     faces = haar_data.detectMultiScale(img)
#       8     for x,y,w,h in faces:
#       9         cv2.rectangle(img,(x,y),(x+w, y+h), (255,0,255),4)
#
# KeyboardInterrupt:
